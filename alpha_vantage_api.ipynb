# %%
from alpha_vantage.timeseries import TimeSeries


key_file = open("/.../github/dev_alpha_vantage_api_key.txt", "r")

key = key_file.read()
ts = TimeSeries(key)
aapl, meta = ts.get_daily(symbol='AMZN')
print(aapl['2019-09-12'])
# Out:
# {'1. open': '1837.6300', '2. high': '1853.6600', '3. low': '1834.2800', '4. close': '1843.5500', '5. volume': '2823500'}

# %%
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.techindicators import TechIndicators
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt

# Your key here
key = key
# Chose your output format, or default to JSON (python dict)
ts = TimeSeries(key, output_format='pandas')
ti = TechIndicators(key)

# Get the data, returns a tuple
# aapl_data is a pandas dataframe, aapl_meta_data is a dict
aapl_data, aapl_meta_data = ts.get_daily(symbol='AMZN')
# aapl_sma is a dict, aapl_meta_sma also a dict
aapl_sma, aapl_meta_sma = ti.get_sma(symbol='AMZN')


# Visualization
figure(num=None, figsize=(15, 6), dpi=80, facecolor='w', edgecolor='k')
aapl_data['4. close'].plot()
plt.tight_layout()
plt.grid()
plt.show()
